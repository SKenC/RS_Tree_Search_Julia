# %%
#include("modules.jl")
#using .MODULE
using Statistics

# %%
include("main.jl")
# Out:
# "@time means = main( d=7,\n                    bf=2,\n                    data_size=100,\n                    rollout_num=1000,\n                    algo_name=\"RS\",\n                    draw=false,\n                    sample_num=1)\n\n@time uctmeans = main( d=7,\n                    bf=2,\n                    data_size=100,\n                    rollout_num=1000,\n                    algo_name=\"UCT\",\n                    draw=false,\n                    sample_num=1)\n\ngraph = hcat(means, uctmeans)\nusing Plots\nplot(means)\nplot(graph)\n"

# %%
@time means = main( d=12,
                    bf=2,
                    data_size=100,
                    rollout_num=1000,
                    algo_name="RS",
                    draw=false,
                    sample_num=1,
                    r=0.9);

# @time uctmeans = main( d=7,
#                     bf=2,
#                     data_size=100,
#                     rollout_num=1000,
#                     algo_name="UCT",
#                     draw=false,
#                     sample_num=1)
# Out:
# Build P-game Tree...OKdata10-data20-data30-data40-data50-data60-data70-data80-data90-data100-MCTS
# data1-data2-data3-data4-data5-data6-data7-data8-data9-data10-data11-data12-data13-data14-data15-data16-data17-data18-data19-data20-data21-data22-data23-data24-data25-data26-data27-data28-data29-data30-data31-data32-data33-data34-data35-data36-data37-data38-data39-data40-data41-data42-data43-data44-data45-data46-data47-data48-data49-data50-data51-data52-data53-data54-data55-data56-data57-data58-data59-data60-data61-data62-data63-data64-data65-data66-data67-data68-data69-data70-data71-data72-data73-data74-data75-data76-data77-data78-data79-data80-data81-data82-data83-data84-data85-data86-data87-data88-data89-data90-data91-data92-data93-data94-data95-data96-data97-data98-data99-data100-  7.537891 seconds (82.04 M allocations: 3.560 GiB, 21.24% gc time)

# %%
# graph = hcat(means, uctmeans)
# using Plots
# plot(graph)

# %%
using Plots
plot(means)

# %%
using CSV
using DataFrames
include("data_save.jl")
#save_csv(data=means, file_name="./exp_data/RS_15d_10000-1.csv", labels=["RS"], gap=1)
# Out:
# save_csv (generic function with 1 method)

# %%
Symbol("aaa")
# Out:
# :aaa

# %%
df DataFrame([[1., 2.], [3., 4.]], [:a, :b])
# Out:
# 2×2 DataFrame
# │ Row │ a       │ b       │
# │     │ Float64 │ Float64 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1.0     │ 3.0     │
# │ 2   │ 2.0     │ 4.0     │
